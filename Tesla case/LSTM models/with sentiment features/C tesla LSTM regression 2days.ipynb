# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from keras.models import Sequential
from keras.layers import *
from keras.utils import *
from keras.optimizers import *
from keras.callbacks import *
from keras.metrics import *
from tensorflow.keras import initializers

# %%
import pandas as pd
import numpy as np
from datetime import datetime

from collections import *
from sklearn.utils import *

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# # Import data

# %%
### import the data
tesla_data = pd.read_csv("..//..//data preparation//4.tesla_twitter_data_aggregated_prices.csv")
#tesla_data = tesla_data.drop(columns=['Subjuctivity','Polarity'])
tesla_data.head()
# Out:
#          date  comment_num  like_num  Subjuctivity   Polarity  \
# 0  2015-01-02           43       136     58.117857  24.628968
# 1  2015-01-03           10        89     19.596165   6.015433
# 2  2015-01-04           11        75     21.760570   7.227273
# 3  2015-01-05           23       201     78.210868  36.700063
# 4  2015-01-06           22       155     57.585345  17.047315
#
#    Class_sentiment_negative  Class_sentiment_neutral  \
# 0                        25                      102
# 1                         6                       58
# 2                         9                       81
# 3                        17                      148
# 4                        20                      150
#
#    Class_sentiment_positive  total_count_tweet       Open      Close  \
# 0                        75                253  14.858000  14.620667
# 1                        26                115  14.858000  14.620667
# 2                        30                155  14.858000  14.620667
# 3                       111                356  14.303333  14.006000
# 4                        65                271  14.004000  14.085333
#
#      change  Class_target
# 0  0.000000           0.0
# 1  0.000000           0.0
# 2  0.000000           0.0
# 3 -4.204097          -1.0
# 4  0.566422           1.0

# %%
tesla_data['date'] = pd.to_datetime(tesla_data['date'])
tesla_data.head()
# Out:
#         date  comment_num  like_num  Subjuctivity   Polarity  \
# 0 2015-01-02           43       136     58.117857  24.628968
# 1 2015-01-03           10        89     19.596165   6.015433
# 2 2015-01-04           11        75     21.760570   7.227273
# 3 2015-01-05           23       201     78.210868  36.700063
# 4 2015-01-06           22       155     57.585345  17.047315
#
#    Class_sentiment_negative  Class_sentiment_neutral  \
# 0                        25                      102
# 1                         6                       58
# 2                         9                       81
# 3                        17                      148
# 4                        20                      150
#
#    Class_sentiment_positive  total_count_tweet       Open      Close  \
# 0                        75                253  14.858000  14.620667
# 1                        26                115  14.858000  14.620667
# 2                        30                155  14.858000  14.620667
# 3                       111                356  14.303333  14.006000
# 4                        65                271  14.004000  14.085333
#
#      change  Class_target
# 0  0.000000           0.0
# 1  0.000000           0.0
# 2  0.000000           0.0
# 3 -4.204097          -1.0
# 4  0.566422           1.0

# %% [markdown]
# ## create target column of from close price : target_close

# %%
tesla_data['target_close'] = tesla_data['Close'].shift(-1)
tesla_data
# Out:
#            date  comment_num  like_num  Subjuctivity    Polarity  \
# 0    2015-01-02           43       136     58.117857   24.628968
# 1    2015-01-03           10        89     19.596165    6.015433
# 2    2015-01-04           11        75     21.760570    7.227273
# 3    2015-01-05           23       201     78.210868   36.700063
# 4    2015-01-06           22       155     57.585345   17.047315
# ...         ...          ...       ...           ...         ...
# 1821 2019-12-28          688      5253    235.425825   62.305687
# 1822 2019-12-29          673      6425    218.909844   42.348362
# 1823 2019-12-30         1494     13014    479.708670  111.280921
# 1824 2019-12-31          936      9674    397.183524  100.569139
# 1825 2020-01-01            5        19      6.353896    2.944098
#
#       Class_sentiment_negative  Class_sentiment_neutral  \
# 0                           25                      102
# 1                            6                       58
# 2                            9                       81
# 3                           17                      148
# 4                           20                      150
# ...                        ...                      ...
# 1821                       112                      227
# 1822                       130                      243
# 1823                       235                      508
# 1824                       193                      453
# 1825                         1                        3
#
#       Class_sentiment_positive  total_count_tweet       Open      Close  \
# 0                           75                253  14.858000  14.620667
# 1                           26                115  14.858000  14.620667
# 2                           30                155  14.858000  14.620667
# 3                          111                356  14.303333  14.006000
# 4                           65                271  14.004000  14.085333
# ...                        ...                ...        ...        ...
# 1821                       310               1549  29.000000  28.691999
# 1822                       259               1471  29.000000  28.691999
# 1823                       615               3559  28.586000  27.646667
# 1824                       480               2212  27.000000  27.888666
# 1825                        10                 16  27.000000  27.888666
#
#         change  Class_target  target_close
# 0     0.000000           0.0     14.620667
# 1     0.000000           0.0     14.620667
# 2     0.000000           0.0     14.006000
# 3    -4.204097          -1.0     14.085333
# 4     0.566422           1.0     14.063333
# ...        ...           ...           ...
# 1821 -0.129954          -1.0     28.691999
# 1822 -0.129954          -1.0     27.646667
# 1823 -3.643287          -1.0     27.888666
# 1824  0.875328           1.0     27.888666
# 1825  0.875328           1.0           NaN
#
# [1826 rows x 14 columns]

# %%
tesla_data = tesla_data.drop([1825])
tesla_data.head()
# Out:
#         date  comment_num  like_num  Subjuctivity   Polarity  \
# 0 2015-01-02           43       136     58.117857  24.628968
# 1 2015-01-03           10        89     19.596165   6.015433
# 2 2015-01-04           11        75     21.760570   7.227273
# 3 2015-01-05           23       201     78.210868  36.700063
# 4 2015-01-06           22       155     57.585345  17.047315
#
#    Class_sentiment_negative  Class_sentiment_neutral  \
# 0                        25                      102
# 1                         6                       58
# 2                         9                       81
# 3                        17                      148
# 4                        20                      150
#
#    Class_sentiment_positive  total_count_tweet       Open      Close  \
# 0                        75                253  14.858000  14.620667
# 1                        26                115  14.858000  14.620667
# 2                        30                155  14.858000  14.620667
# 3                       111                356  14.303333  14.006000
# 4                        65                271  14.004000  14.085333
#
#      change  Class_target  target_close
# 0  0.000000           0.0     14.620667
# 1  0.000000           0.0     14.620667
# 2  0.000000           0.0     14.006000
# 3 -4.204097          -1.0     14.085333
# 4  0.566422           1.0     14.063333

# %%
tesla_data.columns
# Out:
# Index(['date', 'comment_num', 'like_num', 'Subjuctivity', 'Polarity',
#        'Class_sentiment_negative', 'Class_sentiment_neutral',
#        'Class_sentiment_positive', 'total_count_tweet', 'Open', 'Close',
#        'change', 'Class_target', 'target_close'],
#       dtype='object')

# %% [markdown]
# ## correlation

# %%
### select the features to work on
Data = tesla_data.copy()
Data = Data[['date',
             'like_num',
             'comment_num',
             'Class_sentiment_negative', 'Class_sentiment_positive', 'Polarity',
             'total_count_tweet',
             'Close',
             'target_close'
            ]]

Data = Data.sort_values(['date'])
Data
# Out:
#            date  like_num  comment_num  Class_sentiment_negative  \
# 0    2015-01-02       136           43                        25
# 1    2015-01-03        89           10                         6
# 2    2015-01-04        75           11                         9
# 3    2015-01-05       201           23                        17
# 4    2015-01-06       155           22                        20
# ...         ...       ...          ...                       ...
# 1820 2019-12-27     13873         1467                       239
# 1821 2019-12-28      5253          688                       112
# 1822 2019-12-29      6425          673                       130
# 1823 2019-12-30     13014         1494                       235
# 1824 2019-12-31      9674          936                       193
#
#       Class_sentiment_positive    Polarity  total_count_tweet      Close  \
# 0                           75   24.628968                253  14.620667
# 1                           26    6.015433                115  14.620667
# 2                           30    7.227273                155  14.620667
# 3                          111   36.700063                356  14.006000
# 4                           65   17.047315                271  14.085333
# ...                        ...         ...                ...        ...
# 1820                       582  109.940483               3659  28.691999
# 1821                       310   62.305687               1549  28.691999
# 1822                       259   42.348362               1471  28.691999
# 1823                       615  111.280921               3559  27.646667
# 1824                       480  100.569139               2212  27.888666
#
#       target_close
# 0        14.620667
# 1        14.620667
# 2        14.006000
# 3        14.085333
# 4        14.063333
# ...            ...
# 1820     28.691999
# 1821     28.691999
# 1822     27.646667
# 1823     27.888666
# 1824     27.888666
#
# [1825 rows x 9 columns]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11, 6)
mask = np.triu(np.ones_like(Data.corr(), dtype=bool))
sns.heatmap(np.abs(Data.corr()), mask=mask, annot=True, cmap='vlag_r', ax=ax)
plt.title('The correlation between features')
# Out:
# Text(0.5, 1.0, 'The correlation between features')

# %%
# select features to use

# %%
### select the eatures to work on
Data = tesla_data.copy()
Data = Data[['date',
             #'like_num',
             #'comment_num',
             'Class_sentiment_negative', 'Class_sentiment_positive', #'Polarity',
             #'total_count_tweet',
             'Close',
             'target_close'
            ]]

Data = Data.sort_values(['date'])

# %% [markdown]
# ## scaling and creating data sequence

# %%
#Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())
trg_min = Data['target_close'].min()
trg_max = Data['target_close'].max()
trg_min,trg_max
# Out:
# (9.578, 28.729334)

# %%
#Scaling each column separately
for c in Data.columns[1:]:
    Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())

# %%
WINDOW_SIZE = 2
data_x, data_y = [], []

for i in range(WINDOW_SIZE,len(Data)):
    data_x.append(Data.iloc[i-WINDOW_SIZE:i, 1:-1])
    data_y.append((Data.iloc[i, -1]))

# %%
data_x, data_y = np.array(data_x), np.array(data_y)

# %% [markdown]
# ## spliting data

# %%
# training-validation data/ testing data
limiter = 8 * (data_x.shape[0] // 10)

trainV_data_x = data_x[:limiter, :, :]
trainV_data_y = data_y[:limiter]

test_data_x = data_x[limiter:, :, :]
test_data_y = data_y[limiter:]

# %%
# training data/ validation data
limiterValid = 8 * (trainV_data_x.shape[0] // 10)

valid_data_x = trainV_data_x[limiterValid:, :, :]
valid_data_y = trainV_data_y[limiterValid:]

train_data_x = trainV_data_x[:limiterValid, :, :]
train_data_y = trainV_data_y[:limiterValid]

# %%
valid_data_x.shape,valid_data_y.shape
# Out:
# ((296, 2, 3), (296,))

# %%
valid_data_y[:10]
# Out:
# array([0.63877185, 0.63877185, 0.70261424, 0.68983879, 0.63689208,
#        0.63330664, 0.61851211, 0.61851211, 0.61851211, 0.59139478])

# %%
train_data_x.shape,train_data_y.shape
# Out:
# ((1160, 2, 3), (1160,))

# %%
train_data_y[:10]
# Out:
# array([0.23121105, 0.23535347, 0.23420473, 0.23305598, 0.21927104,
#        0.21927104, 0.21927104, 0.20378043, 0.21088176, 0.17064085])

# %%
test_data_x.shape,test_data_y.shape
# Out:
# ((367, 2, 3), (367,))

# %%
test_data_y[:10]
# Out:
# array([0.65837012, 0.65837012, 0.57942006, 0.54544503, 0.60577154,
#        0.60577154, 0.60577154, 0.66588923, 0.66724684, 0.67831651])

# %% [markdown]
# # Training

# %%
kernel_initializer=initializers.RandomNormal(stddev=0.01)
initializer = tf.keras.initializers.RandomUniform(minval=0., maxval=1.)

model = Sequential()

model.add(LSTM(units=60, activation='relu',
               input_shape=(int(train_data_x.shape[1]),int(train_data_x.shape[2])),
               return_sequences=True))

model.add(LSTM(units=35 ,return_sequences=False))
model.add(Dense(1))
model.add(Activation('relu'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 2, 60)             15360
#
#  lstm_1 (LSTM)               (None, 35)                13440
#
#  dense (Dense)               (None, 1)                 36
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 28,836
# Trainable params: 28,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
def r2(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=[r2])

# %%
history = model.fit(train_data_x, train_data_y, epochs=100, batch_size=48, validation_data=(valid_data_x, valid_data_y), verbose=1, callbacks=[
    ReduceLROnPlateau(monitor="val_r2", patience=15, factor=.1),
    EarlyStopping(monitor="val_loss", min_delta=1e-2, patience=45)
])
# Out:
# Epoch 1/100
# 25/25 [==============================] - 6s 64ms/step - loss: 0.1337 - r2: -2.5126 - val_loss: 0.1360 - val_r2: -35.4437 - lr: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0325 - r2: 0.1417 - val_loss: 0.0073 - val_r2: -0.3771 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0164 - r2: 0.5652 - val_loss: 0.0101 - val_r2: -1.9937 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0095 - r2: 0.7446 - val_loss: 0.0049 - val_r2: -0.2604 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0037 - r2: 0.9013 - val_loss: 0.0035 - val_r2: 0.2474 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0012 - r2: 0.9669 - val_loss: 0.0038 - val_r2: 0.1705 - lr: 0.0010
# Epoch 7/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0010 - r2: 0.9721 - val_loss: 0.0036 - val_r2: 0.2046 - lr: 0.0010
# Epoch 8/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.9093e-04 - r2: 0.9740 - val_loss: 0.0035 - val_r2: 0.2293 - lr: 0.0010
# Epoch 9/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.4298e-04 - r2: 0.9747 - val_loss: 0.0035 - val_r2: 0.2425 - lr: 0.0010
# Epoch 10/100
# 25/25 [==============================] - 0s 9ms/step - loss: 9.0245e-04 - r2: 0.9758 - val_loss: 0.0035 - val_r2: 0.2320 - lr: 0.0010
# Epoch 11/100
# 25/25 [==============================] - 0s 8ms/step - loss: 8.6024e-04 - r2: 0.9768 - val_loss: 0.0035 - val_r2: 0.2477 - lr: 0.0010
# Epoch 12/100
# 25/25 [==============================] - 0s 8ms/step - loss: 8.4989e-04 - r2: 0.9741 - val_loss: 0.0035 - val_r2: 0.2650 - lr: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 0s 8ms/step - loss: 8.2866e-04 - r2: 0.9773 - val_loss: 0.0034 - val_r2: 0.2761 - lr: 0.0010
# Epoch 14/100
# 25/25 [==============================] - 0s 7ms/step - loss: 8.2215e-04 - r2: 0.9784 - val_loss: 0.0034 - val_r2: 0.2925 - lr: 0.0010
# Epoch 15/100
# 25/25 [==============================] - 0s 8ms/step - loss: 8.0908e-04 - r2: 0.9785 - val_loss: 0.0035 - val_r2: 0.2541 - lr: 0.0010
# Epoch 16/100
# 25/25 [==============================] - 0s 8ms/step - loss: 8.3363e-04 - r2: 0.9725 - val_loss: 0.0034 - val_r2: 0.2904 - lr: 0.0010
# Epoch 17/100
# 25/25 [==============================] - 0s 8ms/step - loss: 8.1696e-04 - r2: 0.9783 - val_loss: 0.0033 - val_r2: 0.2982 - lr: 1.0000e-04
# Epoch 18/100
# 25/25 [==============================] - 0s 7ms/step - loss: 8.0103e-04 - r2: 0.9776 - val_loss: 0.0033 - val_r2: 0.2949 - lr: 1.0000e-04
# Epoch 19/100
# 25/25 [==============================] - 0s 8ms/step - loss: 8.0121e-04 - r2: 0.9774 - val_loss: 0.0033 - val_r2: 0.2959 - lr: 1.0000e-04
# Epoch 20/100
# 25/25 [==============================] - 0s 11ms/step - loss: 7.9926e-04 - r2: 0.9777 - val_loss: 0.0033 - val_r2: 0.2939 - lr: 1.0000e-04
# Epoch 21/100
# 25/25 [==============================] - 0s 8ms/step - loss: 8.0051e-04 - r2: 0.9764 - val_loss: 0.0033 - val_r2: 0.2952 - lr: 1.0000e-04
# Epoch 22/100
# 25/25 [==============================] - 0s 10ms/step - loss: 7.9850e-04 - r2: 0.9786 - val_loss: 0.0033 - val_r2: 0.2969 - lr: 1.0000e-04
# Epoch 23/100
# 25/25 [==============================] - 0s 7ms/step - loss: 8.0257e-04 - r2: 0.9774 - val_loss: 0.0033 - val_r2: 0.2976 - lr: 1.0000e-04
# Epoch 24/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9905e-04 - r2: 0.9792 - val_loss: 0.0033 - val_r2: 0.2966 - lr: 1.0000e-04
# Epoch 25/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9822e-04 - r2: 0.9777 - val_loss: 0.0033 - val_r2: 0.2950 - lr: 1.0000e-04
# Epoch 26/100
# 25/25 [==============================] - 0s 11ms/step - loss: 8.0307e-04 - r2: 0.9772 - val_loss: 0.0033 - val_r2: 0.2953 - lr: 1.0000e-04
# Epoch 27/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9919e-04 - r2: 0.9786 - val_loss: 0.0033 - val_r2: 0.2964 - lr: 1.0000e-04
# Epoch 28/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9741e-04 - r2: 0.9780 - val_loss: 0.0033 - val_r2: 0.2963 - lr: 1.0000e-04
# Epoch 29/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9571e-04 - r2: 0.9781 - val_loss: 0.0033 - val_r2: 0.2955 - lr: 1.0000e-04
# Epoch 30/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9586e-04 - r2: 0.9795 - val_loss: 0.0033 - val_r2: 0.2963 - lr: 1.0000e-04
# Epoch 31/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9530e-04 - r2: 0.9781 - val_loss: 0.0033 - val_r2: 0.2971 - lr: 1.0000e-04
# Epoch 32/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9434e-04 - r2: 0.9791 - val_loss: 0.0033 - val_r2: 0.2971 - lr: 1.0000e-05
# Epoch 33/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9440e-04 - r2: 0.9724 - val_loss: 0.0033 - val_r2: 0.2971 - lr: 1.0000e-05
# Epoch 34/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9470e-04 - r2: 0.9784 - val_loss: 0.0033 - val_r2: 0.2971 - lr: 1.0000e-05
# Epoch 35/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9437e-04 - r2: 0.9784 - val_loss: 0.0033 - val_r2: 0.2973 - lr: 1.0000e-05
# Epoch 36/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9433e-04 - r2: 0.9778 - val_loss: 0.0033 - val_r2: 0.2974 - lr: 1.0000e-05
# Epoch 37/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9461e-04 - r2: 0.9782 - val_loss: 0.0033 - val_r2: 0.2972 - lr: 1.0000e-05
# Epoch 38/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9426e-04 - r2: 0.9772 - val_loss: 0.0033 - val_r2: 0.2972 - lr: 1.0000e-05
# Epoch 39/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9430e-04 - r2: 0.9787 - val_loss: 0.0033 - val_r2: 0.2974 - lr: 1.0000e-05
# Epoch 40/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9419e-04 - r2: 0.9783 - val_loss: 0.0033 - val_r2: 0.2974 - lr: 1.0000e-05
# Epoch 41/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9417e-04 - r2: 0.9791 - val_loss: 0.0033 - val_r2: 0.2975 - lr: 1.0000e-05
# Epoch 42/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9437e-04 - r2: 0.9785 - val_loss: 0.0033 - val_r2: 0.2974 - lr: 1.0000e-05
# Epoch 43/100
# 25/25 [==============================] - 0s 8ms/step - loss: 7.9421e-04 - r2: 0.9789 - val_loss: 0.0033 - val_r2: 0.2974 - lr: 1.0000e-05
# Epoch 44/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9392e-04 - r2: 0.9789 - val_loss: 0.0033 - val_r2: 0.2975 - lr: 1.0000e-05
# Epoch 45/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9386e-04 - r2: 0.9789 - val_loss: 0.0033 - val_r2: 0.2977 - lr: 1.0000e-05
# Epoch 46/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9409e-04 - r2: 0.9790 - val_loss: 0.0033 - val_r2: 0.2976 - lr: 1.0000e-05
# Epoch 47/100
# 25/25 [==============================] - 0s 7ms/step - loss: 7.9373e-04 - r2: 0.9747 - val_loss: 0.0033 - val_r2: 0.2976 - lr: 1.0000e-06

# %%
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='Validation_loss')
plt.legend()

# %%
plt.plot(history.history['r2'], label='training')
plt.plot(history.history['val_r2'], label='Validation')
plt.legend()

# %%
predictions = model.predict(test_data_x)
# Out:
# 12/12 [==============================] - 1s 3ms/step

# %%
Predictions = []
for i in range(len(predictions)):
    Predictions.append(predictions[i]*(trg_max-trg_min)+trg_min)

# %%
results = {'date' : tesla_data.date[limiter+WINDOW_SIZE:],
           'original': tesla_data.target_close[limiter+WINDOW_SIZE:],
          'predictions':Predictions
          }
df_results = pd.DataFrame(results) 
df_results.date = pd.to_datetime(df_results.date)
df_results.index = df_results.date

fig, ax = plt.subplots(figsize=(8,4))
ax.set_facecolor('#FFFFFF')
ax.plot(df_results['original'], color='dodgerblue', label='Original price')
plt.plot(df_results['predictions'], color='orangered', label='Predicted price')
plt.title('Test data vs prediction for close price all data')
plt.legend()

# %%
r2 = r2_score(df_results['original'], df_results['predictions'])
mse = mean_squared_error(df_results['original'], df_results['predictions'])
mae = mean_absolute_error(df_results['original'], df_results['predictions'])
rmse = np.sqrt(mse)
print('R2 score is -> ', r2)
print('RMSE is -> ', rmse)
# Out:
# R2 score is ->  0.9456071548130298
# RMSE is ->  0.8387978596490576

# %%
df_results
# Out:
#                  date   original  predictions
# date
# 2018-12-30 2018-12-30  22.186666  [22.274813]
# 2018-12-31 2018-12-31  22.186666  [22.362467]
# 2019-01-01 2019-01-01  20.674667  [22.382725]
# 2019-01-02 2019-01-02  20.024000  [22.224209]
# 2019-01-03 2019-01-03  21.179333   [21.84447]
# ...               ...        ...          ...
# 2019-12-27 2019-12-27  28.691999  [29.168293]
# 2019-12-28 2019-12-28  28.691999   [29.87659]
# 2019-12-29 2019-12-29  27.646667  [29.609375]
# 2019-12-30 2019-12-30  27.888666  [29.417042]
# 2019-12-31 2019-12-31  27.888666  [29.355167]
#
# [367 rows x 3 columns]
