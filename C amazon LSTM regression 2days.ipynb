# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from keras.models import Sequential
from keras.layers import *
from keras.utils import *
from keras.optimizers import *
from keras.callbacks import *
from keras.metrics import *
from tensorflow.keras import initializers

# %%
import pandas as pd
import numpy as np
from datetime import datetime

from collections import *
from sklearn.utils import *

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# # Import data

# %%
### import the data
amazon_data = pd.read_csv("..//..//data preparation//4.amazon_twitter_data_aggregated_prices.csv")
amazon_data.head()
# Out:
#          date  comment_num  like_num  Subjuctivity   Polarity  \
# 0  2015-01-02           10        88     44.106540   3.825316
# 1  2015-01-03            3        52     12.579978   3.455700
# 2  2015-01-04            3        43     16.978333   4.842500
# 3  2015-01-05           14       130     56.148954  22.619850
# 4  2015-01-06           11       139     53.996380  16.087120
#
#    Class_sentiment_negative  Class_sentiment_neutral  \
# 0                        35                       89
# 1                        10                       45
# 2                         8                       58
# 3                        22                      186
# 4                        25                      119
#
#    Class_sentiment_positive  total_count_tweet     Open    Close    change  \
# 0                        45                540  15.6290  15.4260  0.000000
# 1                        15                 81  15.6290  15.4260  0.000000
# 2                        17                107  15.6290  15.4260  0.000000
# 3                        71                332  15.3505  15.1095 -2.051731
# 4                        63                273  15.1120  14.7645 -2.283332
#
#    Class_target
# 0           0.0
# 1           0.0
# 2           0.0
# 3          -1.0
# 4          -1.0

# %%
amazon_data['date'] = pd.to_datetime(amazon_data['date'])
amazon_data.head()
# Out:
#         date  comment_num  like_num  Subjuctivity   Polarity  \
# 0 2015-01-02           10        88     44.106540   3.825316
# 1 2015-01-03            3        52     12.579978   3.455700
# 2 2015-01-04            3        43     16.978333   4.842500
# 3 2015-01-05           14       130     56.148954  22.619850
# 4 2015-01-06           11       139     53.996380  16.087120
#
#    Class_sentiment_negative  Class_sentiment_neutral  \
# 0                        35                       89
# 1                        10                       45
# 2                         8                       58
# 3                        22                      186
# 4                        25                      119
#
#    Class_sentiment_positive  total_count_tweet     Open    Close    change  \
# 0                        45                540  15.6290  15.4260  0.000000
# 1                        15                 81  15.6290  15.4260  0.000000
# 2                        17                107  15.6290  15.4260  0.000000
# 3                        71                332  15.3505  15.1095 -2.051731
# 4                        63                273  15.1120  14.7645 -2.283332
#
#    Class_target
# 0           0.0
# 1           0.0
# 2           0.0
# 3          -1.0
# 4          -1.0

# %% [markdown]
# ## create target column from close price : target_close

# %%
amazon_data['target_close'] = amazon_data['Close'].shift(-1)
amazon_data
# Out:
#            date  comment_num  like_num  Subjuctivity   Polarity  \
# 0    2015-01-02           10        88     44.106540   3.825316
# 1    2015-01-03            3        52     12.579978   3.455700
# 2    2015-01-04            3        43     16.978333   4.842500
# 3    2015-01-05           14       130     56.148954  22.619850
# 4    2015-01-06           11       139     53.996380  16.087120
# ...         ...          ...       ...           ...        ...
# 1821 2019-12-28          144      1393     65.543312  21.729725
# 1822 2019-12-29           62       580     50.266318  18.140458
# 1823 2019-12-30          142      1334    168.356250  57.430292
# 1824 2019-12-31          160      1037    159.315592  51.076145
# 1825 2020-01-01            0         6      1.486508   0.842857
#
#       Class_sentiment_negative  Class_sentiment_neutral  \
# 0                           35                       89
# 1                           10                       45
# 2                            8                       58
# 3                           22                      186
# 4                           25                      119
# ...                        ...                      ...
# 1821                        27                       82
# 1822                        13                       56
# 1823                        62                      211
# 1824                        79                      181
# 1825                         0                        2
#
#       Class_sentiment_positive  total_count_tweet       Open      Close  \
# 0                           45                540  15.629000  15.426000
# 1                           15                 81  15.629000  15.426000
# 2                           17                107  15.629000  15.426000
# 3                           71                332  15.350500  15.109500
# 4                           63                273  15.112000  14.764500
# ...                        ...                ...        ...        ...
# 1821                        85                697  94.146004  93.489998
# 1822                        83                445  94.146004  93.489998
# 1823                       243                771  93.699997  92.344498
# 1824                       221                715  92.099998  92.391998
# 1825                         4                  7  92.099998  92.391998
#
#         change  Class_target  target_close
# 0     0.000000           0.0     15.426000
# 1     0.000000           0.0     15.426000
# 2     0.000000           0.0     15.109500
# 3    -2.051731          -1.0     14.764500
# 4    -2.283332          -1.0     14.921000
# ...        ...           ...           ...
# 1821  0.055115           1.0     93.489998
# 1822  0.055115           1.0     92.344498
# 1823 -1.225265          -1.0     92.391998
# 1824  0.051438           1.0     92.391998
# 1825  0.051438           1.0           NaN
#
# [1826 rows x 14 columns]

# %%
amazon_data = amazon_data.drop([1825])
amazon_data.head()
# Out:
#         date  comment_num  like_num  Subjuctivity   Polarity  \
# 0 2015-01-02           10        88     44.106540   3.825316
# 1 2015-01-03            3        52     12.579978   3.455700
# 2 2015-01-04            3        43     16.978333   4.842500
# 3 2015-01-05           14       130     56.148954  22.619850
# 4 2015-01-06           11       139     53.996380  16.087120
#
#    Class_sentiment_negative  Class_sentiment_neutral  \
# 0                        35                       89
# 1                        10                       45
# 2                         8                       58
# 3                        22                      186
# 4                        25                      119
#
#    Class_sentiment_positive  total_count_tweet     Open    Close    change  \
# 0                        45                540  15.6290  15.4260  0.000000
# 1                        15                 81  15.6290  15.4260  0.000000
# 2                        17                107  15.6290  15.4260  0.000000
# 3                        71                332  15.3505  15.1095 -2.051731
# 4                        63                273  15.1120  14.7645 -2.283332
#
#    Class_target  target_close
# 0           0.0       15.4260
# 1           0.0       15.4260
# 2           0.0       15.1095
# 3          -1.0       14.7645
# 4          -1.0       14.9210

# %%
amazon_data.columns
# Out:
# Index(['date', 'comment_num', 'like_num', 'Subjuctivity', 'Polarity',
#        'Class_sentiment_negative', 'Class_sentiment_neutral',
#        'Class_sentiment_positive', 'total_count_tweet', 'Open', 'Close',
#        'change', 'Class_target', 'target_close'],
#       dtype='object')

# %% [markdown]
# ## correlation

# %%
### select the features to work on
Data = amazon_data.copy()
Data = Data[['date',
             'like_num',
             'comment_num',
             'Class_sentiment_negative', 'Class_sentiment_positive', 'Polarity',
             'total_count_tweet',
             'Close',
             'target_close'
            ]]

Data = Data.sort_values(['date'])
Data
# Out:
#            date  like_num  comment_num  Class_sentiment_negative  \
# 0    2015-01-02        88           10                        35
# 1    2015-01-03        52            3                        10
# 2    2015-01-04        43            3                         8
# 3    2015-01-05       130           14                        22
# 4    2015-01-06       139           11                        25
# ...         ...       ...          ...                       ...
# 1820 2019-12-27      3642          431                       117
# 1821 2019-12-28      1393          144                        27
# 1822 2019-12-29       580           62                        13
# 1823 2019-12-30      1334          142                        62
# 1824 2019-12-31      1037          160                        79
#
#       Class_sentiment_positive    Polarity  total_count_tweet      Close  \
# 0                           45    3.825316                540  15.426000
# 1                           15    3.455700                 81  15.426000
# 2                           17    4.842500                107  15.426000
# 3                           71   22.619850                332  15.109500
# 4                           63   16.087120                273  14.764500
# ...                        ...         ...                ...        ...
# 1820                       452  116.786030               1613  93.489998
# 1821                        85   21.729725                697  93.489998
# 1822                        83   18.140458                445  93.489998
# 1823                       243   57.430292                771  92.344498
# 1824                       221   51.076145                715  92.391998
#
#       target_close
# 0        15.426000
# 1        15.426000
# 2        15.109500
# 3        14.764500
# 4        14.921000
# ...            ...
# 1820     93.489998
# 1821     93.489998
# 1822     92.344498
# 1823     92.391998
# 1824     92.391998
#
# [1825 rows x 9 columns]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11, 6)
mask = np.triu(np.ones_like(Data.corr(), dtype=bool))
sns.heatmap(np.abs(Data.corr()), mask=mask, annot=True, cmap='vlag_r', ax=ax)
plt.title('The correlation between features')
# Out:
# Text(0.5, 1.0, 'The correlation between features')

# %%
# select features to use

# %%
### select the eatures to work on
Data = amazon_data.copy()
Data = Data[['date',
             'like_num',
             #'comment_num',
             #'Class_sentiment_negative', 'Class_sentiment_positive', 'Polarity',
             'total_count_tweet',
             'Close',
             'target_close'
            ]]

Data = Data.sort_values(['date'])

# %% [markdown]
# ## scaling and creating data sequence

# %%
#Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())
trg_min = Data['target_close'].min()
trg_max = Data['target_close'].max()
trg_min,trg_max
# Out:
# (14.3475, 101.975502)

# %%
#Scaling each column separately
for c in Data.columns[1:]:
    Data[c] = (Data[c] - Data[c].min()) / (Data[c].max() - Data[c].min())

# %%
WINDOW_SIZE = 2
data_x, data_y = [], []

for i in range(WINDOW_SIZE,len(Data)):
    data_x.append(Data.iloc[i-WINDOW_SIZE:i, 1:-1])
    data_y.append((Data.iloc[i, -1]))

# %%
data_x, data_y = np.array(data_x), np.array(data_y)

# %% [markdown]
# ## spliting data

# %%
limiter = 8 * (data_x.shape[0] // 10)

trainV_data_x = data_x[:limiter, :, :]
trainV_data_y = data_y[:limiter]

test_data_x = data_x[limiter:, :, :]
test_data_y = data_y[limiter:]

# %%
limiterValid = 8 * (trainV_data_x.shape[0] // 10)

valid_data_x = trainV_data_x[limiterValid:, :, :]
valid_data_y = trainV_data_y[limiterValid:]

train_data_x = trainV_data_x[:limiterValid, :, :]
train_data_y = trainV_data_y[:limiterValid]

# %%
valid_data_x.shape,valid_data_y.shape
# Out:
# ((296, 2, 3), (296,))

# %%
valid_data_y[:10]
# Out:
# array([0.73717308, 0.73717308, 0.74829964, 0.74247382, 0.74408296,
#        0.73913014, 0.73305905, 0.73305905, 0.73305905, 0.71779564])

# %%
train_data_x.shape,train_data_y.shape
# Out:
# ((1160, 2, 3), (1160,))

# %%
train_data_y[:10]
# Out:
# array([0.00869585, 0.00475875, 0.00654471, 0.00770872, 0.00569453,
#        0.00569453, 0.00569453, 0.00254485, 0.00444493, 0.00360615])

# %%
test_data_x.shape,test_data_y.shape
# Out:
# ((367, 2, 3), (367,))

# %%
test_data_y[:10]
# Out:
# array([0.69328299, 0.69328299, 0.71448619, 0.69231865, 0.73517597,
#        0.73517597, 0.73517597, 0.76605652, 0.78150249, 0.78312297])

# %% [markdown]
# # Training

# %%
kernel_initializer=initializers.RandomNormal(stddev=0.01)
initializer = tf.keras.initializers.RandomUniform(minval=0., maxval=1.)

model = Sequential()


model.add(LSTM(units=60, activation='relu',
               input_shape=(int(train_data_x.shape[1]),int(train_data_x.shape[2])),
               return_sequences=True))


model.add(LSTM(units=35 ,return_sequences=False))
model.add(Dense(1))
model.add(Activation('relu'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 2, 60)             15360
#
#  lstm_1 (LSTM)               (None, 35)                13440
#
#  dense (Dense)               (None, 1)                 36
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 28,836
# Trainable params: 28,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
def r2(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=[r2])

# %%
history = model.fit(train_data_x, train_data_y, epochs=100, batch_size=48, validation_data=(valid_data_x, valid_data_y), verbose=1, callbacks=[
    ReduceLROnPlateau(monitor="val_r2", patience=15, factor=.1),
    EarlyStopping(monitor="val_loss", min_delta=1e-2, patience=45)
])
# Out:
# Epoch 1/100
# 25/25 [==============================] - 6s 53ms/step - loss: 0.0588 - r2: -1.5634 - val_loss: 0.3084 - val_r2: -232.7576 - lr: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0171 - r2: 0.2609 - val_loss: 0.1211 - val_r2: -89.3939 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0112 - r2: 0.5276 - val_loss: 0.0920 - val_r2: -68.9048 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0058 - r2: 0.7484 - val_loss: 0.0166 - val_r2: -12.3013 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0012 - r2: 0.9516 - val_loss: 0.0072 - val_r2: -3.5431 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 0s 8ms/step - loss: 3.2060e-04 - r2: 0.9856 - val_loss: 0.0040 - val_r2: -1.4496 - lr: 0.0010
# Epoch 7/100
# 25/25 [==============================] - 0s 9ms/step - loss: 1.8960e-04 - r2: 0.9915 - val_loss: 0.0024 - val_r2: -0.4527 - lr: 0.0010
# Epoch 8/100
# 25/25 [==============================] - 0s 8ms/step - loss: 1.4704e-04 - r2: 0.9935 - val_loss: 0.0019 - val_r2: -0.1801 - lr: 0.0010
# Epoch 9/100
# 25/25 [==============================] - 0s 8ms/step - loss: 1.3508e-04 - r2: 0.9942 - val_loss: 0.0017 - val_r2: -0.0666 - lr: 0.0010
# Epoch 10/100
# 25/25 [==============================] - 0s 8ms/step - loss: 1.2279e-04 - r2: 0.9949 - val_loss: 0.0016 - val_r2: 0.0049 - lr: 0.0010
# Epoch 11/100
# 25/25 [==============================] - 0s 8ms/step - loss: 1.1579e-04 - r2: 0.9944 - val_loss: 0.0015 - val_r2: 0.0712 - lr: 0.0010
# Epoch 12/100
# 25/25 [==============================] - 0s 7ms/step - loss: 1.1220e-04 - r2: 0.9947 - val_loss: 0.0015 - val_r2: 0.0655 - lr: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 0s 7ms/step - loss: 1.1015e-04 - r2: 0.9952 - val_loss: 0.0013 - val_r2: 0.1605 - lr: 0.0010
# Epoch 14/100
# 25/25 [==============================] - 0s 8ms/step - loss: 1.1232e-04 - r2: 0.9953 - val_loss: 0.0014 - val_r2: 0.1319 - lr: 0.0010
# Epoch 15/100
# 25/25 [==============================] - 0s 7ms/step - loss: 1.0623e-04 - r2: 0.9955 - val_loss: 0.0012 - val_r2: 0.2001 - lr: 0.0010
# Epoch 16/100
# 25/25 [==============================] - 0s 8ms/step - loss: 1.0338e-04 - r2: 0.9956 - val_loss: 0.0012 - val_r2: 0.2027 - lr: 0.0010
# Epoch 17/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.9752e-05 - r2: 0.9948 - val_loss: 0.0013 - val_r2: 0.1977 - lr: 1.0000e-04
# Epoch 18/100
# 25/25 [==============================] - 0s 9ms/step - loss: 1.0056e-04 - r2: 0.9957 - val_loss: 0.0013 - val_r2: 0.1978 - lr: 1.0000e-04
# Epoch 19/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.9062e-05 - r2: 0.9958 - val_loss: 0.0013 - val_r2: 0.1968 - lr: 1.0000e-04
# Epoch 20/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.9829e-05 - r2: 0.9957 - val_loss: 0.0013 - val_r2: 0.1951 - lr: 1.0000e-04
# Epoch 21/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.9364e-05 - r2: 0.9956 - val_loss: 0.0013 - val_r2: 0.1995 - lr: 1.0000e-04
# Epoch 22/100
# 25/25 [==============================] - 0s 9ms/step - loss: 9.8768e-05 - r2: 0.9957 - val_loss: 0.0013 - val_r2: 0.2028 - lr: 1.0000e-04
# Epoch 23/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.8909e-05 - r2: 0.9958 - val_loss: 0.0012 - val_r2: 0.2090 - lr: 1.0000e-04
# Epoch 24/100
# 25/25 [==============================] - 0s 9ms/step - loss: 9.8967e-05 - r2: 0.9956 - val_loss: 0.0013 - val_r2: 0.2052 - lr: 1.0000e-04
# Epoch 25/100
# 25/25 [==============================] - 0s 9ms/step - loss: 9.8207e-05 - r2: 0.9957 - val_loss: 0.0013 - val_r2: 0.2076 - lr: 1.0000e-04
# Epoch 26/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.8315e-05 - r2: 0.9953 - val_loss: 0.0012 - val_r2: 0.2207 - lr: 1.0000e-04
# Epoch 27/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.7846e-05 - r2: 0.9959 - val_loss: 0.0012 - val_r2: 0.2148 - lr: 1.0000e-04
# Epoch 28/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.7703e-05 - r2: 0.9959 - val_loss: 0.0012 - val_r2: 0.2178 - lr: 1.0000e-04
# Epoch 29/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.7613e-05 - r2: 0.9957 - val_loss: 0.0012 - val_r2: 0.2180 - lr: 1.0000e-04
# Epoch 30/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.7421e-05 - r2: 0.9958 - val_loss: 0.0012 - val_r2: 0.2253 - lr: 1.0000e-04
# Epoch 31/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.7394e-05 - r2: 0.9957 - val_loss: 0.0012 - val_r2: 0.2240 - lr: 1.0000e-04
# Epoch 32/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.7195e-05 - r2: 0.9955 - val_loss: 0.0012 - val_r2: 0.2267 - lr: 1.0000e-05
# Epoch 33/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.7113e-05 - r2: 0.9960 - val_loss: 0.0012 - val_r2: 0.2294 - lr: 1.0000e-05
# Epoch 34/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.7069e-05 - r2: 0.9959 - val_loss: 0.0012 - val_r2: 0.2307 - lr: 1.0000e-05
# Epoch 35/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.7017e-05 - r2: 0.9958 - val_loss: 0.0012 - val_r2: 0.2304 - lr: 1.0000e-05
# Epoch 36/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.7027e-05 - r2: 0.9956 - val_loss: 0.0012 - val_r2: 0.2301 - lr: 1.0000e-05
# Epoch 37/100
# 25/25 [==============================] - 0s 9ms/step - loss: 9.6978e-05 - r2: 0.9956 - val_loss: 0.0012 - val_r2: 0.2305 - lr: 1.0000e-05
# Epoch 38/100
# 25/25 [==============================] - 0s 9ms/step - loss: 9.7035e-05 - r2: 0.9959 - val_loss: 0.0012 - val_r2: 0.2286 - lr: 1.0000e-05
# Epoch 39/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.6971e-05 - r2: 0.9956 - val_loss: 0.0012 - val_r2: 0.2305 - lr: 1.0000e-05
# Epoch 40/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.6950e-05 - r2: 0.9956 - val_loss: 0.0012 - val_r2: 0.2323 - lr: 1.0000e-05
# Epoch 41/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.6928e-05 - r2: 0.9958 - val_loss: 0.0012 - val_r2: 0.2321 - lr: 1.0000e-05
# Epoch 42/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.7035e-05 - r2: 0.9955 - val_loss: 0.0012 - val_r2: 0.2331 - lr: 1.0000e-05
# Epoch 43/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.6993e-05 - r2: 0.9955 - val_loss: 0.0012 - val_r2: 0.2303 - lr: 1.0000e-05
# Epoch 44/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.6874e-05 - r2: 0.9948 - val_loss: 0.0012 - val_r2: 0.2304 - lr: 1.0000e-05
# Epoch 45/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.6874e-05 - r2: 0.9958 - val_loss: 0.0012 - val_r2: 0.2308 - lr: 1.0000e-05
# Epoch 46/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.6905e-05 - r2: 0.9958 - val_loss: 0.0012 - val_r2: 0.2298 - lr: 1.0000e-05
# Epoch 47/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.6817e-05 - r2: 0.9959 - val_loss: 0.0012 - val_r2: 0.2300 - lr: 1.0000e-06
# Epoch 48/100
# 25/25 [==============================] - 0s 8ms/step - loss: 9.6812e-05 - r2: 0.9958 - val_loss: 0.0012 - val_r2: 0.2298 - lr: 1.0000e-06
# Epoch 49/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.6810e-05 - r2: 0.9957 - val_loss: 0.0012 - val_r2: 0.2298 - lr: 1.0000e-06
# Epoch 50/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.6805e-05 - r2: 0.9958 - val_loss: 0.0012 - val_r2: 0.2302 - lr: 1.0000e-06
# Epoch 51/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.6805e-05 - r2: 0.9958 - val_loss: 0.0012 - val_r2: 0.2303 - lr: 1.0000e-06

# %%
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='Validation_loss')
plt.legend()

# %%
plt.plot(history.history['r2'], label='training')
plt.plot(history.history['val_r2'], label='Validation')
plt.legend()

# %%
predictions = model.predict(test_data_x)
# Out:
# 12/12 [==============================] - 1s 3ms/step

# %%
Predictions = []
for i in range(len(predictions)):
    Predictions.append(predictions[i]*(trg_max-trg_min)+trg_min)

# %%
results = {'date' : amazon_data.date[limiter+WINDOW_SIZE:],
           'original': amazon_data.target_close[limiter+WINDOW_SIZE:],
          'predictions':Predictions
          }
df_results = pd.DataFrame(results) 
df_results.date = pd.to_datetime(df_results.date)
df_results.index = df_results.date

fig, ax = plt.subplots(figsize=(8,4))
ax.set_facecolor('#FFFFFF')
ax.plot(df_results['original'], color='dodgerblue', label='Original price')
plt.plot(df_results['predictions'], color='orangered', label='Predicted price')
plt.title('Test data vs prediction for close price all data')
plt.legend()

# %%
r2 = r2_score(df_results['original'], df_results['predictions'])
mse = mean_squared_error(df_results['original'], df_results['predictions'])
mae = mean_absolute_error(df_results['original'], df_results['predictions'])
rmse = np.sqrt(mse)
print('R2 score is -> ', r2)
print('RMSE is -> ', rmse)
# Out:
# R2 score is ->  0.813979075357822
# RMSE is ->  2.2218522677066135

# %%
df_results
# Out:
#                  date   original  predictions
# date
# 2018-12-30 2018-12-30  75.098503   [74.59703]
# 2018-12-31 2018-12-31  75.098503   [73.63159]
# 2019-01-01 2019-01-01  76.956497   [74.09325]
# 2019-01-02 2019-01-02  75.014000  [74.883446]
# 2019-01-03 2019-01-03  78.769501   [76.17572]
# ...               ...        ...          ...
# 2019-12-27 2019-12-27  93.489998   [92.43701]
# 2019-12-28 2019-12-28  93.489998  [101.49634]
# 2019-12-29 2019-12-29  92.344498   [98.70856]
# 2019-12-30 2019-12-30  92.391998   [94.69054]
# 2019-12-31 2019-12-31  92.391998   [93.73329]
#
# [367 rows x 3 columns]
